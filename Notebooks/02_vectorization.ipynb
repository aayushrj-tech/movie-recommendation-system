# %%
import pandas as pd

df = pd.read_csv("../data/movies_cleaned.csv")
print(df.shape)
df.head()
# Out:
# (9994, 8)
#        id                     title  \
# 0  851644         20th Century Girl
# 1     238             The Godfather
# 2     278  The Shawshank Redemption
# 3     240     The Godfather Part II
# 4  667257         Impossible Things
#
#                                             overview  \
# 0  Yeon-du asks her best friend Bora to collect a...
# 1  Spanning the years 1945 to 1955, a chronicle o...
# 2  Framed in the 1940s for the double murder of h...
# 3  In the continuing saga of the Corleone crime f...
# 4  Matilde is a woman who, after the death of her...
#
#                                                 text original_language  \
# 0  20th century girl yeon-du asks her best friend...                ko
# 1  the godfather spanning the years 1945 to 1955,...                en
# 2  the shawshank redemption framed in the 1940s f...                en
# 3  the godfather part ii in the continuing saga o...                en
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    stop_words="english",
    max_features=5000
)

# %%
movie_vectors = tfidf.fit_transform(df["text"])

movie_vectors.shape
# Out:
# (9994, 5000)

# %%
import pickle

with open("../data/tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(tfidf, f)

with open("../data/movie_vectors.pkl", "wb") as f:
    pickle.dump(movie_vectors, f)

print("Vectorization completed and saved")
# Out:
# Vectorization completed and saved

# %%
import os

print(os.path.getsize("../data/tfidf_vectorizer.pkl"))
print(os.path.getsize("../data/movie_vectors.pkl"))
# Out:
# 183317
# 2397131
